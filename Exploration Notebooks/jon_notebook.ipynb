# %% [markdown]
# insert header

# %% [markdown]
# # Title

# %% [markdown]
# ## Business Understanding and Business Problem

# %% [markdown]
# ### Cost of Errors

# %% [markdown]
# ## Data Understanding

# %%
#imports grabbed from lecture
from random import gauss as gs, uniform as uni, seed
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from surprise import Reader, Dataset

from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD
from surprise.prediction_algorithms import KNNWithMeans, KNNBasic, KNNBaseline
from surprise.model_selection import GridSearchCV

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Initial Data

# %%
#the four csv files provided
links_df = pd.read_csv('data/links.csv')
movies_df = pd.read_csv('data/movies.csv')
ratings_df = pd.read_csv('data/ratings.csv')
tags_df = pd.read_csv('data/tags.csv')

# %%
links_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
simple_ratings_df = ratings_df.drop('timestamp', axis=1)

# %%
simple_ratings_df.head(5)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
simple_ratings_df.info(), simple_ratings_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   userId   100836 non-null  int64
#  1   movieId  100836 non-null  int64
#  2   rating   100836 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 2.3 MB
# (None,
#  userId     0
#  movieId    0
#  rating     0
#  dtype: int64)

# %%
# reader = Reader()
# data = Dataset.load_from_df(simple_ratings_df,reader)

# %%
# dataset = data.build_full_trainset()
# print('Number of users: ', dataset.n_users, '\n')
# print('Number of items: ', dataset.n_items)

# %% [markdown]
# ## Modeling

# %%
# params = {'n_factors': [20, 50, 100],
#          'reg_all': [0.02, 0.05, 0.1]}
# g_s_svd = GridSearchCV(SVD,param_grid=params,n_jobs=-1)
# g_s_svd.fit(data)

# %%
# print(g_s_svd.best_score)
# print(g_s_svd.best_params)

# %%
# # cross validating with KNNBasic
# knn_basic = KNNBasic(sim_options={'name':'pearson', 'user_based':True})
# cv_knn_basic = cross_validate(knn_basic, data, n_jobs=-1)

# %%
# for i in cv_knn_basic.items():
#     print(i)
# print('-----------------------')
# print(np.mean(cv_knn_basic['test_rmse']))

# %%
# # cross validating with KNNBaseline
# knn_baseline = KNNBaseline(sim_options={'name':'pearson', 'user_based':True})
# cv_knn_baseline = cross_validate(knn_baseline,data)

# %%
# for i in cv_knn_baseline.items():
#     print(i)

# np.mean(cv_knn_baseline['test_rmse'])

# %% [markdown]
# ## SPLIT GENRE

# %%
movies_df.head(1)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
genres_df = movies_df[['movieId', 'genres']]
genres_df.head(1)
# Out:
#    movieId                                       genres
# 0        1  Adventure|Animation|Children|Comedy|Fantasy

# %%
genres_df['genres'][0].split('|')
# Out:
# ['Adventure', 'Animation', 'Children', 'Comedy', 'Fantasy']

# %%
genres_df['genres'][0]
# Out:
# 'Adventure|Animation|Children|Comedy|Fantasy'

# %%
# # Split single column into two columns use apply()
# df[['First Name', 'Last Name']] = df["Student_details"].apply(lambda x: pd.Series(str(x).split(",")))
# print(df)

# %%
genres_df['split_genres'] = genres_df['genres'].iloc[0:].apply(lambda x: x.lower().split('|'))
genres_df.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                                         split_genres
# 0  [adventure, animation, children, comedy, fantasy]
# 1                     [adventure, children, fantasy]
# 2                                  [comedy, romance]
# 3                           [comedy, drama, romance]
# 4                                           [comedy]

# %%
# genres_df['genres'] = genres_df['genres'].apply(lambda x: x.split('|'))
# genres_df['genres'].head()

# %% [markdown]
# ## CLEAN TAGS

# %%
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags_df['tag_clean'] = tags_df['tag'].iloc[0:].apply(lambda x: x.lower().replace(' ', ''))
tags_df['tag_clean'].head()
# Out:
# 0             funny
# 1    highlyquotable
# 2       willferrell
# 3       boxingstory
# 4               mma
# Name: tag_clean, dtype: object

# %%
tags_df['tag_clean'].value_counts()
# Out:
# innetflixqueue       131
# atmospheric           41
# thought-provoking     24
# surreal               24
# superhero             24
#                     ...
# mice                   1
# dr.seuss               1
# slowpaced              1
# exciting               1
# motherfucker           1
# Name: tag_clean, Length: 1471, dtype: int64

# %% [markdown]
# ## Combining some columns to use

# %%
# I can remove timestamp, will join on movieId
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings_df_clean = ratings_df.drop('timestamp', axis=1)
ratings_df_clean.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
#can remove tag, timestamp
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp       tag_clean
# 0       2    60756            funny  1445714994           funny
# 1       2    60756  Highly quotable  1445714996  highlyquotable
# 2       2    60756     will ferrell  1445714992     willferrell
# 3       2    89774     Boxing story  1445715207     boxingstory
# 4       2    89774              MMA  1445715200             mma

# %%
tags_df_clean = tags_df.drop(['tag', 'timestamp'], axis=1)
tags_df_clean.head()
# Out:
#    userId  movieId       tag_clean
# 0       2    60756           funny
# 1       2    60756  highlyquotable
# 2       2    60756     willferrell
# 3       2    89774     boxingstory
# 4       2    89774             mma

# %%
# can remove genres
genres_df.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                                         split_genres
# 0  [adventure, animation, children, comedy, fantasy]
# 1                     [adventure, children, fantasy]
# 2                                  [comedy, romance]
# 3                           [comedy, drama, romance]
# 4                                           [comedy]

# %%
genres_df_clean = genres_df.drop('genres', axis=1)
genres_df_clean.head()
# Out:
#    movieId                                       split_genres
# 0        1  [adventure, animation, children, comedy, fantasy]
# 1        2                     [adventure, children, fantasy]
# 2        3                                  [comedy, romance]
# 3        4                           [comedy, drama, romance]
# 4        5                                           [comedy]

# %%
#merging
genre_rating_df = genres_df_clean.merge(ratings_df_clean, how='outer', on='movieId')
genre_rating_df
# Out:
#         movieId                                       split_genres  userId  \
# 0             1  [adventure, animation, children, comedy, fantasy]     1.0
# 1             1  [adventure, animation, children, comedy, fantasy]     5.0
# 2             1  [adventure, animation, children, comedy, fantasy]     7.0
# 3             1  [adventure, animation, children, comedy, fantasy]    15.0
# 4             1  [adventure, animation, children, comedy, fantasy]    17.0
# ...         ...                                                ...     ...
# 100849   193581               [action, animation, comedy, fantasy]   184.0
# 100850   193583                       [animation, comedy, fantasy]   184.0
# 100851   193585                                            [drama]   184.0
# 100852   193587                                [action, animation]   184.0
# 100853   193609                                           [comedy]   331.0
#
#         rating
# 0          4.0
# 1          4.0
# 2          4.5
# 3          2.5
# 4          4.5
# ...        ...
# 100849     4.0
# 100850     3.5
# 100851     3.5
# 100852     3.5
# 100853     4.0
#
# [100854 rows x 4 columns]

# %%
genre_rating_df.isna().sum()
# Out:
# movieId          0
# split_genres     0
# userId          18
# rating          18
# dtype: int64

# %%
genre_rating_df.dropna(inplace=True)

# %% [markdown]
# ## Transform Dataset into a Network Graph using NetworkX

# %%
# import networkx as nx

# G = nx.Graph()
# for row in genre_rating_df.index:
#     movie = genre_rating_df.movieId[row]
#     user = genre_rating_df.userId[row]
#     rating = genre_rating_df.rating[row]
#     G.add_edge(movie, user, weight=rating)
# print(len(G.nodes))

# %% [markdown]
# ### Initial Graph Viz

# %%
# plt.figure(figsize=(35,20))
# nx.draw(G, pos=nx.spring_layout(G, k=2, seed=10), with_labels=True,
#         alpha=.8, node_size=20000, font_weight='bold', font_size=18)

# %%
# #refining visual
# for i in range(0,100,5):
#     print('{}th percentile: {}'.format(i,genre_rating_df.rating.quantile(q=i/100)))

# %%
# threshold = 4.5
# G_subset = nx.Graph()
# for row in genre_rating_df.index:
#     movie = genre_rating_df.movieId[row]
#     user = genre_rating_df.userId[row]
#     rating = genre_rating_df.rating[row]
#     if rating > threshold:
#         G_subset.add_edge(movie, user, weight=rating)
# plt.figure(figsize=(30,20))
# nx.draw(G_subset, pos=nx.spring_layout(G_subset, k=2, seed=5),
#         alpha=.8, node_color='#32cefe', node_size=5000,
#         with_labels=True, font_size=12, font_weight='bold')

# %%
# len(G_subset)

# %%
# threshold = 4.9
# G_subset = nx.Graph()
# for row in genre_rating_df.index:
#     movie = genre_rating_df.movieId[row]
#     user = genre_rating_df.userId[row]
#     rating = genre_rating_df.rating[row]
#     if rating > threshold:
#         G_subset.add_edge(movie, user, weight=rating)
# plt.figure(figsize=(30,20))
# nx.draw(G_subset, pos=nx.spring_layout(G_subset, k=2, seed=5),
#         alpha=.8, node_color='#32cefe', node_size=5000,
#         with_labels=True, font_size=12, font_weight='bold')

# %%
# len(G_subset)

# %%
# # clustering the network
# gn_clusters = list(nx.algorithms.community.centrality.girvan_newman(G_subset))
# for n, clusters in enumerate(gn_clusters):
#     print('After removing {} edges, there are {} clusters.'.format(n, len(clusters)))

# %% [markdown]
# ## Revisiting EDA with cleaned data

# %%
genre_rating_df.head(50)
# Out:
#     movieId                                       split_genres  userId  rating
# 0         1  [adventure, animation, children, comedy, fantasy]     1.0     4.0
# 1         1  [adventure, animation, children, comedy, fantasy]     5.0     4.0
# 2         1  [adventure, animation, children, comedy, fantasy]     7.0     4.5
# 3         1  [adventure, animation, children, comedy, fantasy]    15.0     2.5
# 4         1  [adventure, animation, children, comedy, fantasy]    17.0     4.5
# 5         1  [adventure, animation, children, comedy, fantasy]    18.0     3.5
# 6         1  [adventure, animation, children, comedy, fantasy]    19.0     4.0
# 7         1  [adventure, animation, children, comedy, fantasy]    21.0     3.5
# 8         1  [adventure, animation, children, comedy, fantasy]    27.0     3.0
# 9         1  [adventure, animation, children, comedy, fantasy]    31.0     5.0
# 10        1  [adventure, animation, children, comedy, fantasy]    32.0     3.0
# 11        1  [adventure, animation, children, comedy, fantasy]    33.0     3.0
# 12        1  [adventure, animation, children, comedy, fantasy]    40.0     5.0
# 13        1  [adventure, animation, children, comedy, fantasy]    43.0     5.0
# 14        1  [adventure, animation, children, comedy, fantasy]    44.0     3.0
# 15        1  [adventure, animation, children, comedy, fantasy]    45.0     4.0
# 16        1  [adventure, animation, children, comedy, fantasy]    46.0     5.0
# 17        1  [adventure, animation, children, comedy, fantasy]    50.0     3.0
# 18        1  [adventure, animation, children, comedy, fantasy]    54.0     3.0
# 19        1  [adventure, animation, children, comedy, fantasy]    57.0     5.0
# 20        1  [adventure, animation, children, comedy, fantasy]    63.0     5.0
# 21        1  [adventure, animation, children, comedy, fantasy]    64.0     4.0
# 22        1  [adventure, animation, children, comedy, fantasy]    66.0     4.0
# 23        1  [adventure, animation, children, comedy, fantasy]    68.0     2.5
# 24        1  [adventure, animation, children, comedy, fantasy]    71.0     5.0
# 25        1  [adventure, animation, children, comedy, fantasy]    73.0     4.5
# 26        1  [adventure, animation, children, comedy, fantasy]    76.0     0.5
# 27        1  [adventure, animation, children, comedy, fantasy]    78.0     4.0
# 28        1  [adventure, animation, children, comedy, fantasy]    82.0     2.5
# 29        1  [adventure, animation, children, comedy, fantasy]    86.0     4.0
# 30        1  [adventure, animation, children, comedy, fantasy]    89.0     3.0
# 31        1  [adventure, animation, children, comedy, fantasy]    90.0     3.0
# 32        1  [adventure, animation, children, comedy, fantasy]    91.0     4.0
# 33        1  [adventure, animation, children, comedy, fantasy]    93.0     3.0
# 34        1  [adventure, animation, children, comedy, fantasy]    96.0     5.0
# 35        1  [adventure, animation, children, comedy, fantasy]    98.0     4.5
# 36        1  [adventure, animation, children, comedy, fantasy]   103.0     4.0
# 37        1  [adventure, animation, children, comedy, fantasy]   107.0     4.0
# 38        1  [adventure, animation, children, comedy, fantasy]   112.0     3.0
# 39        1  [adventure, animation, children, comedy, fantasy]   119.0     3.5
# 40        1  [adventure, animation, children, comedy, fantasy]   121.0     4.0
# 41        1  [adventure, animation, children, comedy, fantasy]   124.0     4.0
# 42        1  [adventure, animation, children, comedy, fantasy]   130.0     3.0
# 43        1  [adventure, animation, children, comedy, fantasy]   132.0     2.0
# 44        1  [adventure, animation, children, comedy, fantasy]   134.0     3.0
# 45        1  [adventure, animation, children, comedy, fantasy]   135.0     4.0
# 46        1  [adventure, animation, children, comedy, fantasy]   137.0     4.0
# 47        1  [adventure, animation, children, comedy, fantasy]   140.0     3.0
# 48        1  [adventure, animation, children, comedy, fantasy]   141.0     4.0
# 49        1  [adventure, animation, children, comedy, fantasy]   144.0     3.5

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list])

# %%
genre_counts_names = to_1D(genre_rating_df['split_genres']).value_counts().index.tolist()
genre_counts_values = to_1D(genre_rating_df['split_genres']).value_counts().values

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(genre_counts_names[:11], genre_counts_values[:11])
# Out:
# <BarContainer object of 11 artists>

# %%
tags_df_clean['tag_clean'].value_counts().index.tolist()
# Out:
# ['innetflixqueue',
#  'atmospheric',
#  'thought-provoking',
#  'surreal',
#  'superhero',
#  'funny',
#  'disney',
#  'sci-fi',
#  'religion',
#  'quirky',
#  'darkcomedy',
#  'suspense',
#  'psychology',
#  'twistending',
#  'visuallyappealing',
#  'comedy',
#  'politics',
#  'crime',
#  'music',
#  'highschool',
#  'dark',
#  'action',
#  'mentalillness',
#  'timetravel',
#  'mindfuck',
#  'aliens',
#  'space',
#  'dreamlike',
#  'blackcomedy',
#  'journalism',
#  'holocaust',
#  'emotional',
#  'disturbing',
#  'heist',
#  'shakespeare',
#  'mafia',
#  'stephenking',
#  'christmas',
#  'satire',
#  'classic',
#  'anime',
#  'court',
#  'comicbook',
#  'animation',
#  'adolescence',
#  'ghosts',
#  'adultery',
#  'bittersweet',
#  'psychological',
#  'boxing',
#  'imdbtop250',
#  'robots',
#  'leonardodicaprio',
#  'philosophical',
#  'vietnam',
#  'england',
#  'australia',
#  'drugs',
#  'cinematography',
#  'india',
#  'remake',
#  'adventure',
#  'mystery',
#  'murder',
#  'stylized',
#  'creepy',
#  'racism',
#  'sexuality',
#  'hallucinatory',
#  'worldwarii',
#  'revenge',
#  'willferrell',
#  'tense',
#  'military',
#  'heartwarming',
#  'bad',
#  'race',
#  'family',
#  'divorce',
#  'coenbrothers',
#  'police',
#  'newyork',
#  'animalmovie',
#  'sequel',
#  'martialarts',
#  'beautiful',
#  'moviebusiness',
#  'serialkiller',
#  'spoof',
#  'violence',
#  'socialcommentary',
#  'prostitution',
#  'disability',
#  'quentintarantino',
#  'darkhumor',
#  'cerebral',
#  'romance',
#  'death',
#  'intelligent',
#  'assassination',
#  'inspirational',
#  'witty',
#  'predictable',
#  'kidnapping',
#  'cultfilm',
#  'bible',
#  'clever',
#  'gritty',
#  'screwball',
#  'magic',
#  'philosophy',
#  'menindrag',
#  'zombies',
#  'dystopia',
#  'soundtrack',
#  'pregnancy',
#  'terrorism',
#  'greatsoundtrack',
#  'twins',
#  'business',
#  'gothic',
#  'pixar',
#  'blackandwhite',
#  'astaireandrogers',
#  'nickandnoracharles',
#  'visuallystunning',
#  'hitmen',
#  'touching',
#  'remade',
#  'future',
#  'depressing',
#  'gambling',
#  'television',
#  'fantasy',
#  'wedding',
#  'bradpitt',
#  'lawyers',
#  'civilwar',
#  'jason',
#  'sarcasm',
#  'deathpenalty',
#  'judaism',
#  'stylish',
#  'benstiller',
#  'hepburnandtracy',
#  'friendship',
#  'adamsandler',
#  'homeless',
#  'existentialism',
#  'poignant',
#  'swashbuckler',
#  'sports',
#  'unique',
#  'fun',
#  'postapocalyptic',
#  'alpacino',
#  'alcoholism',
#  'aardman',
#  'paranoia',
#  'sad',
#  'amnesia',
#  'ireland',
#  'post-apocalyptic',
#  'ryanreynolds',
#  'dogs',
#  'samurai',
#  'thriller',
#  'artificialintelligence',
#  'humorous',
#  'africa',
#  'baseball',
#  'dickens',
#  'crossdressing',
#  'epic',
#  'biopic',
#  'wizards',
#  'gooddialogue',
#  'spaceopera',
#  'president',
#  'marriage',
#  'corruption',
#  'horror',
#  'organizedcrime',
#  'basedonabook',
#  'tolkein',
#  'archaeology',
#  'martinscorsese',
#  'edwardnorton',
#  'stevecarell',
#  'truestory',
#  'horses',
#  'johngrisham',
#  'oscar(bestactress)',
#  'melancholy',
#  'memory',
#  'intense',
#  'crudehumor',
#  'fatherhood',
#  'sethrogen',
#  'moving',
#  'prison',
#  'christianbale',
#  'alfredhitchcock',
#  'paranoid',
#  'movies',
#  'assassin',
#  'food',
#  'violent',
#  'hughjackman',
#  'immigrants',
#  'generationx',
#  'samuell.jackson',
#  'basketball',
#  'weird',
#  'interesting',
#  'janeausten',
#  'feel-good',
#  'blindness',
#  'showbusiness',
#  'survival',
#  'basedonatvshow',
#  'plotholes',
#  'controversial',
#  'heartbreaking',
#  'marvel',
#  'birds',
#  'badplot',
#  'loneliness',
#  'tomhanks',
#  'enigmatic',
#  'kingarthur',
#  'priest',
#  'parody',
#  'circus',
#  'demons',
#  'inspiring',
#  'writing',
#  'slasher',
#  'shakespearesortof',
#  'orphans',
#  'golf',
#  'boring',
#  'christophernolan',
#  'bloody',
#  'drama',
#  'childabuse',
#  'terminalillness',
#  'basedonatruestory',
#  'tolkien',
#  'spacetravel',
#  'timburton',
#  'documentary',
#  'alternatereality',
#  'robinwilliams',
#  'suspenseful',
#  'spying',
#  'artistic',
#  'greatacting',
#  'off-beatcomedy',
#  'motherhood',
#  'jakegyllenhaal',
#  'tomhardy',
#  'photography',
#  'children',
#  'nonlinear',
#  'dialogue',
#  'transplants',
#  'anti-semitism',
#  'nasa',
#  'robertdeniro',
#  'japan',
#  '06oscarnominatedbestmovie-animation',
#  'stevebuscemi',
#  'italy',
#  'brutality',
#  'guns',
#  'class',
#  'liamneeson',
#  'dance',
#  'masterpiece',
#  'tennesseewilliams',
#  '1970s',
#  'coldwar',
#  'mathematics',
#  'blind',
#  'claustrophobic',
#  'gangsters',
#  'hilarious',
#  'dccomics',
#  'evilchildren',
#  'highlyquotable',
#  'whimsical',
#  'books',
#  'hitman',
#  'britishcomedy',
#  'train',
#  'jacknicholson',
#  'jimcarrey',
#  'obsession',
#  'mockumentary',
#  'awesome',
#  'classicsci-fi',
#  'clousseau',
#  'starwars',
#  'lovestory',
#  'multiplestorylines',
#  'brucewillis',
#  'tarantino',
#  'girlpower',
#  'ensemblecast',
#  'insanity',
#  'sweet',
#  'benaffleck',
#  'e.m.forster',
#  'halloween',
#  'rome',
#  'michaelcera',
#  'football',
#  'nightclub',
#  'overrated',
#  'goodsoundtrack',
#  'psychedelic',
#  'silly',
#  'irreverent',
#  'fantasyworld',
#  'rachelweisz',
#  'mademecry',
#  'hollywood',
#  'smart',
#  'batman',
#  'reflective',
#  'aids',
#  'stanleykubrick',
#  'original',
#  'scandal',
#  'lawyer',
#  'hanniballecter',
#  'musicbusiness',
#  'lyrical',
#  'sentimental',
#  'conspiracytheory',
#  'twists&turns',
#  'goofy',
#  'teen',
#  'understated',
#  'henryjames',
#  'christopherlloyd',
#  'audienceintelligenceunderestimated',
#  'virginity',
#  'ridiculous',
#  'c.s.lewis',
#  'cultclassic',
#  'fbi',
#  'alternateendings',
#  'heroineintightsuit',
#  'm.nightshyamalan',
#  'espionage',
#  'trains',
#  'symbolism',
#  'jamesfranco',
#  'college',
#  'arthouse',
#  'neo-noir',
#  'rogersandhammerstein',
#  'melgibson',
#  'spaceaction',
#  'romantic',
#  'fish',
#  '1920s',
#  'france',
#  'robzombie',
#  'futuristic',
#  'spaghettiwestern',
#  'marxbrothers',
#  'dating',
#  'quotable',
#  'imagination',
#  'gangster',
#  'psychologicalthriller',
#  'claymation',
#  'widows/widowers',
#  'darthvader',
#  'cyberpunk',
#  'surfing',
#  'characterstudy',
#  'heroicbloodshed',
#  'rape',
#  'seenmorethanonce',
#  'theater',
#  'drugabuse',
#  'capote',
#  'school',
#  'freaks',
#  'indianajones',
#  'schizophrenia',
#  'notablesoundtrack',
#  'greatending',
#  'originalplot',
#  'morganfreeman',
#  'stupidending',
#  'keanureeves',
#  'toolong',
#  'longshots',
#  'eerie',
#  'tragic',
#  'figureskating',
#  'island',
#  'downbeat',
#  'depression',
#  'cambodia',
#  'babies',
#  'shark',
#  'edithwharton',
#  'markruffalo',
#  'seannwilliamscott',
#  'darkhero',
#  'treasurehunt',
#  'notavailablefromnetflix',
#  'notseen',
#  'raybradbury',
#  'greatdialogue',
#  'vampire',
#  'moody',
#  '1980s',
#  'jamesstewart',
#  'jaredleto',
#  'christinaricci',
#  'personalsads',
#  'newyorkcity',
#  'beautifulscenery',
#  'bleak',
#  '1950s',
#  'badacting',
#  'pow',
#  'lastmanonearth',
#  'narrated',
#  'offensive',
#  'scary',
#  'reunion',
#  'unconventional',
#  'missionary',
#  'sniper',
#  'southamerica',
#  'meditative',
#  'badscript',
#  'annehathaway',
#  'morality',
#  'nudity(fullfrontal)',
#  'gangs',
#  'time-travel',
#  'moon',
#  'judelaw',
#  'twist',
#  'greatperformances',
#  'bromance',
#  'art',
#  'union',
#  'alternateuniverse',
#  'europe',
#  'graphicdesign',
#  'china',
#  'cancer',
#  'retro',
#  'willsmith',
#  'amish',
#  'rasicm',
#  'paulgiamatti',
#  'humor',
#  'fairytales',
#  'veryfunny',
#  'chrisevans',
#  'radio',
#  'war',
#  'wallstreet',
#  'bigbudget',
#  'myth',
#  'doctors',
#  'cult',
#  'robertdowneyjr.',
#  'christophwaltz',
#  'western',
#  'satirical',
#  'chickflick',
#  'badwriting',
#  'non-linear',
#  'psychiatrist',
#  'hemingway',
#  'studioghibli',
#  'trippy',
#  'jessicaalba',
#  'peterpan',
#  'ironic',
#  'tv',
#  'jeanreno',
#  'violenceinamerica',
#  'apocalypse',
#  'coma',
#  'humour',
#  'georgebernardshaw',
#  'weddings',
#  'dinosaurs',
#  'cynical',
#  'arnoldschwarzenegger',
#  'nazis',
#  'grahamgreene',
#  'plottwist',
#  'vampires',
#  'ballet',
#  'heroin',
#  'helenabonhamcarter',
#  'sexyfemalescientist',
#  'intellectual',
#  'complicated',
#  'surrealism',
#  'reciprocalspectator',
#  'paulrudd',
#  'whiteguilt',
#  'secretsociety',
#  'tearjerker',
#  'love',
#  'startrek',
#  'slick',
#  'olympics',
#  'brutal',
#  'poetic',
#  'agathachristie',
#  'charlizetheron',
#  'harsh',
#  'stevenspielberg',
#  'mentalhospital',
#  'tomclancy',
#  'factory',
#  'lukeskywalker',
#  'michaelbay',
#  'butler',
#  'brainwashing',
#  'spacecraft',
#  'powerfulending',
#  'nickhornby',
#  'courtroomdrama',
#  'artsy',
#  'scificult',
#  'jeffbridges',
#  'psychopaths',
#  'characters',
#  'fugitive',
#  'chess',
#  'confrontational',
#  'jazz',
#  'submarine',
#  'l.a.',
#  'adoption',
#  'orlandobloom',
#  'goldenwatch',
#  'soccer',
#  'emiliaclarke',
#  'conan',
#  'brilliant',
#  'dumb',
#  'franchise',
#  'scifi',
#  'oscar(bestcinematography)',
#  'harrypotter',
#  'androids',
#  'women',
#  'cheeky',
#  'evagreen',
#  'truth',
#  'selfdiscovery',
#  'preacher',
#  'historical',
#  'waytoolong',
#  'andykaufman',
#  'dumpsterdiving',
#  'simonpegg',
#  'indonesia',
#  'travolta',
#  'pageant',
#  'different',
#  'nabokov',
#  'wapendrama',
#  'foullanguage',
#  'televangelist',
#  'sisters',
#  'evolution',
#  'threesome',
#  'jesseeisenberg',
#  'stonesofsummer',
#  'fightingthesystem',
#  'intimate',
#  'families',
#  'smartwriting',
#  'politicalcommentary',
#  'klingons',
#  'homosexuality',
#  'opera',
#  'cartoon',
#  'robbery',
#  'river',
#  'embarassingscenes',
#  'nudity(topless)',
#  'siam',
#  'beautifullyfilmed',
#  'anneboleyn',
#  'non-lineartimeline',
#  'happyending',
#  'canada',
#  'post-college',
#  'film-noir',
#  'trumancapote',
#  'inyoureyes',
#  'magneto',
#  'goodandevil',
#  'stupidbutfunny',
#  'rug',
#  'undercovercop',
#  'random',
#  'leonardodicarpio',
#  'individualism',
#  'sciencefiction',
#  'ericbana',
#  'nuclearwar',
#  'hotactress',
#  'couldabeenacontender',
#  'ichabodcrane',
#  'ptsd',
#  'ritahayworthcandance!',
#  'hope',
#  'adingoatemybaby',
#  'pearlsbuck',
#  'dinosaur',
#  'marijuana',
#  'remixculture',
#  'veterinarian',
#  'housekeeper',
#  'nonlinearnarrative',
#  'freedomofexpression',
#  'secrets',
#  'horridcharacterisation',
#  'intertwiningstorylines',
#  'kids',
#  'nonlineartimeline',
#  'weatherforecaster',
#  'macho',
#  'organisedcrime',
#  'filmnoir',
#  'interracialmarriage',
#  'hostage',
#  'neededmoreautobots',
#  'splatter',
#  'r:strongbloodyviolence',
#  'ewanmcgregor',
#  'quakers',
#  'disjointedtimeline',
#  'galgadot',
#  'history',
#  'toto',
#  'motivational',
#  'relaxing',
#  'royalwithcheese',
#  'tension',
#  'britpop',
#  'crazy',
#  'coolstyle',
#  'harleyquinn',
#  'mecha',
#  'holygrail',
#  'aloneintheworld',
#  'lesbiansubtext',
#  'spiders',
#  'stockmarket',
#  'insightful',
#  'lieutenantdan',
#  'coleporter',
#  'rlanguage',
#  'happpiness',
#  'storytelling',
#  'bigcorporations',
#  'superbsoundtrack',
#  'standup',
#  'imaginative',
#  'poordialogue',
#  'backwards.memory',
#  'carnival',
#  'inhumane',
#  'cruelcharacters',
#  'johngoodman',
#  'acting',
#  'swordfight',
#  'pizzabeer',
#  'nathanfillion',
#  'charlesdickens',
#  'nodvdatnetflix',
#  'adrienbrody',
#  'blackhumor',
#  'fairytale',
#  'filmhistory',
#  'rap',
#  'aviation',
#  'kevincostner',
#  'domesticviolence',
#  'infertility',
#  'menacing',
#  'halleberry',
#  'tricky',
#  'multiplestories',
#  'tedious',
#  'vangogh',
#  'youngermen',
#  'itwasmelodramaticandkindofdumb',
#  'prodigies',
#  'bigbrothers',
#  'blood',
#  'prom',
#  'snl',
#  'brothers',
#  'consumerism',
#  'gold',
#  'cheating',
#  'good',
#  'confusingending',
#  'cattledrive',
#  'colorful',
#  'dr.strange',
#  'captainamerica',
#  'hungary',
#  'zooeydeschanel',
#  'katzanzakis',
#  'wrongfulimprisonment',
#  'pudding',
#  'poorlypaced',
#  'josswhedon',
#  'specialeffects',
#  'slavery',
#  'saints',
#  'guardiansofthegalaxy',
#  'r:violence',
#  'billmurray',
#  'asylum',
#  'mind-blowing',
#  'interestingcharacters',
#  'queenvictoria',
#  'largecast',
#  'superficialplot',
#  'abstract',
#  'oninous',
#  'exquisiteplotting.',
#  'buildingafamily',
#  'incest',
#  'russia',
#  'johnmalkovich',
#  'welldone',
#  'doll',
#  'americanindians',
#  'grim',
#  'claimstobetrue',
#  'johnnydepp',
#  'california',
#  'salutetodouglassirk',
#  'aliciavikander',
#  'innovative',
#  'pool',
#  'toomanycharacters',
#  'robertpennwarren',
#  'independent',
#  'actionpacked',
#  'solitude',
#  'cateblanchett',
#  'remaster',
#  'asbyatt',
#  'kevinspacey',
#  'beethoven',
#  "palmed'or",
#  'spaceepic',
#  'restaurant',
#  'melancholic',
#  'rebellion',
#  'heavymetal',
#  'bears',
#  'abortion',
#  'ships',
#  'michigan',
#  'may-decemberromance',
#  'e-mail',
#  'pigs',
#  'assassin-in-training(scene)',
#  'six-fingeredman',
#  'boxingstory',
#  'juliannemoore',
#  'mma',
#  'newcomposer',
#  'strange',
#  'brittanymurphy',
#  'anthonyhopkins',
#  'philipseymourhoffman',
#  'lougehrig',
#  'casino',
#  'southafrica',
#  'petawilson',
#  'shangri-la',
#  'mobster',
#  'prince',
#  'francisfordcoppola',
#  'fast-paceddialogue',
#  'jungle',
#  'hawkeye',
#  'angelinajolie',
#  'awkwardromance',
#  'colourful',
#  'lasvegas',
#  'mccarthyhearings',
#  'lion',
#  'insurance',
#  'tildaswinton',
#  'umathurman',
#  'oil',
#  'cgi',
#  'addiction',
#  'dayandhudson',
#  'natalieportman',
#  'disneyanimatedfeature',
#  'nativeamericans',
#  'horribleacting',
#  'chuckpalahniuk',
#  'deepthroat',
#  'emma',
#  'amyadams',
#  'beautifulvisuals',
#  'somber',
#  'baddialogue',
#  'shipwreck',
#  '1960s',
#  'stonermovie',
#  'ninotchkaremake',
#  'dorothy',
#  'policecorruption',
#  'uncomfortable',
#  'golfing',
#  'peeweeherman',
#  'masculinity',
#  'lonesomepolecat',
#  'updatedclassics',
#  'skiing',
#  'bad-ass',
#  'joshbrolin',
#  'prejudice',
#  'bizzare',
#  'ransom',
#  'milakunis',
#  'r:sustainedstrongstylizedviolence',
#  'toga',
#  'diabetes',
#  'reneezellweger',
#  'danielradcliffe',
#  'arthurc.clarke',
#  'geeky',
#  'amazingcinematography',
#  'lloyddobbler',
#  'spaceadventure',
#  'faerietale',
#  'money',
#  'classicmovie',
#  'academyaward(bestsupportingactress)',
#  'turkey',
#  'bigboyswithguns',
#  'scottturow',
#  'greatcinematography',
#  'fatalistic',
#  'roalddahl',
#  'unexplained',
#  'childishnaivity',
#  'titanic',
#  'multipleshortstories',
#  'henrydarger',
#  'interracialromance',
#  'palahnuik',
#  'lolitatheme',
#  'paris',
#  'dwaynejohnson',
#  'badmusic',
#  'hulahoop',
#  'mirrors',
#  'smalltowns',
#  'unpredictable',
#  'casualviolence',
#  'longing',
#  'enterprise',
#  'creaturefeature',
#  'irony',
#  'technology',
#  'citypolitics',
#  'gruesome',
#  'characterdevelopment',
#  'nonlinearstoryline',
#  'edharris',
#  'scifimasterpiece',
#  'leopard',
#  'theentertainer',
#  'busniess',
#  'basedonaplay',
#  'postmodern',
#  'iconic',
#  'romanticcomedy',
#  'badstory',
#  'blackhole',
#  'marioncotillard',
#  'hearst',
#  'lucbesson',
#  'jenniferlawrence',
#  'rosebud',
#  'lies',
#  'oscarwilde',
#  'empirestatebuilding',
#  'elegant',
#  'rogue',
#  'episodic',
#  'truckers',
#  'intelligentsci-fi',
#  'wonderwoman',
#  'liveaction/animation',
#  'interestingscenario',
#  'badlanguage',
#  'acleverchefrat',
#  'tensionbuilding',
#  'computeranimation',
#  'dreamy',
#  'emmastone',
#  'nicolascage',
#  'investorcorruption',
#  'audreytautou',
#  'garyoldman',
#  'juliettelewis',
#  'realestate',
#  'photographer',
#  'passion',
#  'jeangrey',
#  'shrimp',
#  'favelas',
#  'johnnycash',
#  'kurtrussell',
#  'challenging',
#  'unsettling',
#  'jamescameron',
#  'saint',
#  'hilaryswank',
#  'earnest',
#  'sexualhumor',
#  'teenagepregnancy',
#  'startofabeautifulfriendship',
#  'voyeurism',
#  'dc',
#  'losangeles',
#  'tearjerking',
#  'creative',
#  'bignameactors',
#  'montypython',
#  'venice',
#  'dumas',
#  'inigomontoya',
#  'politicalrightversusleft',
#  'nostalgia',
#  'meaninglessviolence',
#  'somethingforeveryoneinthisone...sawitwithoutandplanonseeingitwithkids!',
#  'fighting',
#  'harrisonford',
#  'everythingyouwantishere',
#  'georgelucas',
#  'rachelmcadams',
#  'tradition!',
#  'musicindustry',
#  'anger',
#  'denzelwashington',
#  'parrots',
#  'doublelife',
#  '1990s',
#  'americanpropaganda',
#  'jaimepressly',
#  'viggomortensen',
#  'recap',
#  'nun',
#  'moses',
#  'multiplepersonalities',
#  'borg',
#  'purityofessence',
#  'smalltimecriminals',
#  'bigwave',
#  'illusions',
#  'black-and-white',
#  'hanniballector',
#  'shialabeouf',
#  'moviesaboutmovies',
#  'celebrityfetishism',
#  'moldy',
#  'cryptic',
#  'financialcrisis',
#  'prequel',
#  'wry',
#  'afghanistan',
#  'actionchoreography',
#  'davidthewlis',
#  ...]

# %%
tag_counts_names = tags_df_clean['tag_clean'].value_counts().index
tag_counts_values = tags_df_clean['tag_clean'].value_counts().values

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(tag_counts_names[:11], tag_counts_values[:11])
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# ## Results/Conclusions

# %% [markdown]
# ### Further Exploration/Questions

# %%
x = [0,1,2,3,4,5]

# %%
fig, ax = plt.subplots()

plt.plot(x, 1,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d6b8a7707f92> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 plt.plot(x, 1,0)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2822 @_copy_docstring_and_deprecators(Axes.plot)
#    2823 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
#    2826         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (6,) and (1,)
